# %%
# import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

from gensim.utils import simple_preprocess
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import torch.nn as nn
from torch.optim import AdamW
from torch.utils.data import Dataset, DataLoader

from transformers import get_linear_schedule_with_warmup, AutoTokenizer, AutoModel, logging

import warnings
warnings.filterwarnings("ignore")

logging.set_verbosity_error()
# read data ignore last col
import py_vncorenlp
import os
def seed_everything(seed_value):
    np.random.seed(seed_value)
    # torch.manual_seed(seed_value)
    
    # if torch.cuda.is_available(): 
    #     torch.cuda.manual_seed(seed_value)
    #     torch.cuda.manual_seed_all(seed_value)
    #     torch.backends.cudnn.deterministic = True
    #     torch.backends.cudnn.benchmark = True



if 'pwd' not in locals():
    from transformers import PhobertTokenizer, AutoModel
    from transformers import DataCollatorForTokenClassification
    pwd = Path(os.getcwd())
    save_dir = pwd / 'models'
    rdrsegmenter = py_vncorenlp.VnCoreNLP(annotators=["wseg"], save_dir=str(save_dir))
    os.chdir(pwd)
    seed_everything(25)

# device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
EPOCHS = 6
N_SPLITS = 5

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

data = pd.read_csv('data - data.csv', usecols=range(0, 3))
data['wseg'] = data['comment'].apply(lambda x : " ".join(simple_preprocess( " ".join(rdrsegmenter.word_segment(x)))))
display(data.sample(10))
# Out:
#                                                  comment label  rate  \
# 11319      Thanks shop, nếu cần nữa sẽ ủng hộ shop tiếp.   POS     4
# 3317                       Không đẹp giống như hình ảnh.   NEG     1
# 11342                     Chúc shop buôn may bán đắt <3.   POS     5
# 849                                              Như củ.   NEG     2
# 18922                            Giày xinh cực luôn 😘😘😘.   POS     4
# 17666                              Áo đẹp xuất sắc luôn.   POS     5
# 12515                                  Túi quần bị rách.   NEG     2
# 3021                              hàng đẹp giống y hình.   POS     4
# 2549                                         Giá hơp lý!   POS     4
# 20868  Đóng gói không đẹp hộp bị rách may không thủng...   NEG     2
#
#                                                     wseg
# 11319        thanks shop nếu cần nữa sẽ ủng_hộ shop tiếp
# 3317                        không đẹp giống như hình_ảnh
# 11342                         chúc shop buôn may bán đắt
# 849                                               như củ
# 18922                                 giày xinh cực luôn
# 17666                               áo đẹp xuất_sắc luôn
# 12515                                   túi quần bị rách
# 3021                                 hàng đẹp giống hình
# 2549                                          giá hơp lý
# 20868  đóng_gói không đẹp hộp bị rách may không thủng...

# %%
vectorizer = TfidfVectorizer(tokenizer = lambda x : x.split(' '))
corpus  = data['wseg'].tolist()
X = vectorizer.fit_transform(corpus)

display(X.shape)
# Out:
# (31460, 6921)

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing



Y = data['label'].tolist()
le = preprocessing.LabelEncoder()
le.fit(Y)
Y = le.transform(Y)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=25)

# %%
# using SVM for classification
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)
svm.score(X_test, y_test)
# Out:
# 0.7817863954227591

# %%
y_pred = svm.predict(X_test)
print(classification_report(y_test, y_pred,  target_names=['POS','NEU','NEG']))
# Out:
#               precision    recall  f1-score   support
#
#          POS       0.68      0.77      0.72      1328
#          NEU       0.48      0.16      0.24       979
#          NEG       0.84      0.94      0.89      3985
#
#     accuracy                           0.78      6292
#    macro avg       0.67      0.62      0.61      6292
# weighted avg       0.75      0.78      0.75      6292

# %%
from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.713 total time=  37.7s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.730 total time=  37.7s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.724 total time=  37.6s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.721 total time=  37.8s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.719 total time=  38.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.670 total time=  38.1s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.676 total time=  37.8s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.674 total time=  38.1s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.672 total time=  38.3s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.668 total time=  38.3s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.640 total time=  40.7s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.640 total time=  40.5s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.640 total time=  40.6s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.640 total time=  40.4s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.640 total time=  40.3s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.640 total time=  38.3s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.640 total time=  38.3s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.640 total time=  38.2s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.640 total time=  38.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.640 total time=  38.7s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  33.6s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  33.6s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  33.6s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  33.6s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  33.7s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.781 total time=  45.6s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.792 total time=  46.1s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.783 total time=  46.4s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.786 total time=  46.8s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.784 total time=  46.9s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.770 total time=  32.4s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.775 total time=  32.4s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.774 total time=  32.3s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.777 total time=  32.2s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.777 total time=  32.3s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.680 total time=  38.1s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.687 total time=  37.9s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.681 total time=  38.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.682 total time=  37.9s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.680 total time=  38.1s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.640 total time=  40.6s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.640 total time=  40.2s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.640 total time=  40.3s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.640 total time=  40.1s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.640 total time=  40.3s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  38.3s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  38.1s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  38.2s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  38.1s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.640 total time=  38.4s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.761 total time= 1.7min
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.779 total time= 1.8min
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.773 total time= 1.7min
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.768 total time= 1.8min
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.775 total time= 1.8min
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.771 total time=  32.1s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.782 total time=  32.5s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.773 total time=  32.4s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.773 total time=  32.6s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.778 total time=  32.5s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.770 total time=  32.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.779 total time=  32.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.775 total time=  31.9s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.776 total time=  31.9s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.778 total time=  31.8s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.680 total time=  38.2s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.687 total time=  38.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.682 total time=  38.1s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.684 total time=  38.1s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.680 total time=  38.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.640 total time=  40.6s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.640 total time=  40.2s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.640 total time=  40.4s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.640 total time=  40.4s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.640 total time=  40.6s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.757 total time= 1.7min
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.776 total time= 1.8min
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.770 total time= 1.7min
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.764 total time= 1.8min
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.773 total time= 1.8min
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.751 total time= 1.3min
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.763 total time= 1.4min
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.759 total time= 1.3min
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.749 total time= 1.3min
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.759 total time= 1.4min
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.769 total time=  31.9s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.778 total time=  32.1s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.771 total time=  32.2s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.769 total time=  32.7s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.773 total time=  32.4s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.771 total time=  32.1s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.778 total time=  32.1s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.775 total time=  32.1s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.776 total time=  32.2s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.778 total time=  32.5s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.680 total time=  38.6s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.688 total time=  38.7s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.682 total time=  38.8s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.684 total time=  38.7s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.680 total time=  38.4s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.757 total time= 1.7min
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.777 total time= 1.7min
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.769 total time= 1.7min
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.762 total time= 1.8min
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.772 total time= 1.8min
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.734 total time= 1.8min
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.747 total time= 1.8min
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.738 total time= 1.8min
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.733 total time= 1.9min
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.741 total time= 2.0min
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.750 total time=  50.1s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.756 total time=  51.3s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.753 total time=  50.5s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.746 total time=  51.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.752 total time=  51.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.768 total time=  31.8s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.779 total time=  31.9s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.770 total time=  31.7s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.770 total time=  31.7s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.773 total time=  31.8s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.771 total time=  31.9s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.778 total time=  31.9s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.775 total time=  31.9s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.776 total time=  31.9s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.778 total time=  31.9s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
y_pred = grid.predict(X_test)
print(classification_report(y_test, y_pred,  target_names=['POS','NEU','NEG']))
print(grid.best_params_)
# Out:
#               precision    recall  f1-score   support
#
#          POS       0.68      0.77      0.72      1328
#          NEU       0.48      0.16      0.24       979
#          NEG       0.84      0.94      0.89      3985
#
#     accuracy                           0.78      6292
#    macro avg       0.67      0.62      0.61      6292
# weighted avg       0.75      0.78      0.75      6292

# %%
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
